# %% [markdown]
# ## Data  Ingestion

# %%
from langchain_core.documents import Document

doc = Document(
    page_content="This is a sample document in a test project that I created.",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author": "Thusitha Kithuldora",
        "created_at": "2026-08-12"
    }
)

doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Thusitha Kithuldora', 'created_at': '2026-08-12'}, page_content='This is a sample document in a test project that I created.')

# %%
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader, DirectoryLoader

dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls= PyMuPDFLoader,
    show_progress=False
)
pdf_documents = dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-17T10:58:47+05:30', 'source': '..\\data\\pdf\\ipd-cover-letter.pdf', 'file_path': '..\\data\\pdf\\ipd-cover-letter.pdf', 'total_pages': 1, 'format': 'PDF 1.7', 'title': '', 'author': 'Thusitha Kithuldora', 'subject': '', 'keywords': '', 'moddate': '2026-07-17T10:58:47+05:30', 'trapped': '', 'modDate': "D:20260717105847+05'30'", 'creationDate': "D:20260717105847+05'30'", 'page': 0}, page_content='Thusitha Kithuldora, \nColombo, Sri Lanka. \n \nHiring Manager, \nIPD Group. \n \nApplication for Web Developer Position \n \nDear Hiring Manager, \nI am writing to express my strong interest in the Web Developer position at IPD Group. With over four \nyears of professional frontend development experience and a deep proficiency in modern frameworks like \nReact and Next.js, I am eager to bring my technical skills to a dynamic, 65-year-old industry leader. IPD \nGroup’s reputation as a trusted, user-centric provider of electrical and EV infrastructure solutions strongly \nresonates with my desire to build high-performance, impactful digital experiences. \nMy technical background aligns closely with your requirements for creating responsive, optimized, and \naccessible web applications. In my previous role as a UI Developer at Kongcepts, I spent nearly four years \ntransforming complex UI/UX designs into pixel-perfect code, managing API integrations, and actively \nsupporting SEO initiatives that boosted organic search discoverability by up to 35%. \nCurrently, I am working at Qoria LK as a Trainee Software Engineer. I took on this specific role as it was a \nmandatory requirement to complete my BSc in Electronics and Computer Science. However, despite the \n"trainee" title, I am heavily engaged in handling advanced, production-level tasks. My day-to-day \nresponsibilities involve architecting complex micro-frontend applications, resolving critical production bugs, \nand spearheading strict WCAG accessibility compliance features. Furthermore, because Qoria is also an \nASX-listed company, I am already highly accustomed to the rigorous standards, cross-functional \ncollaboration, and accountability expected within an environment like IPD Group. \nI am confident in my ability to handle the advanced responsibilities outlined in your job description, from \ncomplex third-party system integrations to application security troubleshooting. Should my academic \ntimeline or current title suggest I am not yet a perfect fit for a senior or mid-level capacity, I would be entirely \nopen and willing to take on responsibilities in a junior role. My primary goal is simply to earn the opportunity \nto prove my capabilities, contribute to your cross-functional Australian teams, and grow alongside IPD \nGroup. \nThank you for your time and consideration. I would welcome the opportunity to discuss how my hands-on \nexperience, problem-solving skills, and drive to deliver exceptional web experiences can add immediate \nvalue to your team. \nSincerely, \nThusitha Kithuldora'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-17T17:52:07+05:30', 'source': '..\\data\\pdf\\olive-tree-cover-letter.pdf', 'file_path': '..\\data\\pdf\\olive-tree-cover-letter.pdf', 'total_pages': 1, 'format': 'PDF 1.7', 'title': '', 'author': 'Thusitha Kithuldora', 'subject': '', 'keywords': '', 'moddate': '2026-07-17T17:52:07+05:30', 'trapped': '', 'modDate': "D:20260717175207+05'30'", 'creationDate': "D:20260717175207+05'30'", 'page': 0}, page_content='Thusitha Kithuldora, \nColombo, Sri Lanka. \n \nHiring Team, \nOlive Tree Consulting Group, \nLondon, United Kingdom. \n \nSubject: Application for Associate Frontend Engineer \n \nDear Hiring Team, \nI am writing to express my interest in the Associate Frontend Engineer position at Olive Tree Consulting \nGroup. Your firm\'s philosophy that "memory is not a management system" and your focus on building \npractical, plain, and reliable digital workspaces strongly resonates with my own approach to software \nengineering. I am highly motivated to help build functional browser-based tools that bridge the gap \nbetween strategy and execution for your London client. \nCurrently completing a BSc in Electronics and Computer Science, I have cultivated a strong foundation in \nmodern JavaScript, HTML5, CSS3, and React. My engineering background is focused on transforming \nwireframes into responsive, pixel-perfect layouts using robust layout techniques and reusable component \nlibraries. I firmly believe that internal tools should prioritize legibility and ease of use over visual complexity, \nand I take pride in writing clean, maintainable code that directly solves organizational problems.  \nFurthermore, your emphasis on web accessibility perfectly aligns with my technical expertise. I have \nextensive hands-on experience engineering strict WCAG accessibility compliance features, ensuring that \ndigital interfaces are reliably accessible via screen readers, ARIA labels, and proper keyboard navigation. I \nknow that for a management tool to be truly useful, it must be functional and professional for every member \nof the client team across any browser.  \nWhile I am based in Sri Lanka, I am fully prepared to work on UK business hours to ensure seamless \nsynchronous collaboration with your London-based client and the wider remote team. I am highly \naccustomed to working in distributed agile environments, relying on clear, written communication to \ndocument updates, ask questions early, and actively participate in code reviews. I am comfortable working \nindependently while staying deeply connected to team objectives.  \nI would welcome the opportunity to bring my technical skills, attention to detail, and dedication to practical \nfunctionality to Olive Tree Consulting. My portfolio and GitHub profile demonstrate my commitment to \nbuilding accessible and structured web applications. \n \nSincerely, \nThusitha Kithuldora'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-17T10:35:14+05:30', 'source': '..\\data\\pdf\\thusitha-kithuldora-cv-ipd.pdf', 'file_path': '..\\data\\pdf\\thusitha-kithuldora-cv-ipd.pdf', 'total_pages': 3, 'format': 'PDF 1.7', 'title': '', 'author': 'Thusitha Kithuldora', 'subject': '', 'keywords': '', 'moddate': '2026-07-17T10:35:14+05:30', 'trapped': '', 'modDate': "D:20260717103514+05'30'", 'creationDate': "D:20260717103514+05'30'", 'page': 0}, page_content='Thusitha Kithuldora \nFull-Stack Software Engineer \nColombo, Sri Lanka | +94762600331 | thusithakit3@gmail.com \nLinkedIn: thusitha-kithuldora | Portfolio: https://www.thusithakit.com \nProfessional Summary \nDetail-oriented Frontend Web Developer with over 4 years of professional experience in \ndesigning, developing, and optimizing high-performance web applications and landing pages. \nProficient in modern frontend frameworks including React and Next.js, with a strong background \nin API consumption and third-party system integrations. Proven ability to implement user-centric \nUI/UX enhancements, support rigorous SEO initiatives, and ensure strict WCAG accessibility \ncompliance. Adept at collaborating with cross-functional teams to troubleshoot issues, refine \nrequirements, and deliver secure, reliable digital experiences in fast-paced environments.  \nTechnical Skills \n• \nFrontend Frameworks & Libraries: React, Next.js (App Router), Redux, Zustand, \nAxios, Vite Module Federation.  \n• \nCore Web Technologies: HTML5, CSS3/SASS, JavaScript (ES6+), TypeScript, \nResponsive Web Design.  \n• \nUI/UX & Design: Tailwind CSS, Chakra UI, Material UI, Figma, Adobe XD, \nComponent-Driven Design.  \n• \nBackend & Integrations: REST APIs, Third-Party System Integrations, Java, Spring \nBoot, Node.Js, Go(Echo).  \n• \nOptimization & Standards: SEO Optimization, WCAG Accessibility Standards, Web \nPerformance Optimization, Progressive Web Apps (PWA).  \n• \nTools & Version Control: Git/GitHub workflows, Vercel, Netlify, Postman, Vitest, \nTroubleshooting & Debugging.  \nProfessional Experience \nTrainee Software Engineer | Qoria LK | Colombo \n Sep 2025 - Present \n• \nTook full ownership of the design and frontend development for the new Public App \nDirectory, delivering a high-impact feature anticipated to drive major adoption for the \nEdTech Manager product during the back-to-school season. \n• \nParticipate actively in agile ceremonies, working cross-functionally with UX designers, \nbackend teams, and product owners to deliver software components. \n• \nInvestigate and resolve critical production bugs, and execute UI/UX enhancements using \nChakra UI and Axios. \n• \nWrite and maintain comprehensive end-to-end and unit testing suites utilizing Vitest, \nCypress, and Playwright to safeguard application stability.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-17T10:35:14+05:30', 'source': '..\\data\\pdf\\thusitha-kithuldora-cv-ipd.pdf', 'file_path': '..\\data\\pdf\\thusitha-kithuldora-cv-ipd.pdf', 'total_pages': 3, 'format': 'PDF 1.7', 'title': '', 'author': 'Thusitha Kithuldora', 'subject': '', 'keywords': '', 'moddate': '2026-07-17T10:35:14+05:30', 'trapped': '', 'modDate': "D:20260717103514+05'30'", 'creationDate': "D:20260717103514+05'30'", 'page': 1}, page_content='• \nEnforce strict engineering best practices and secure code standards by integrating \nSonarQube and Snyk into the development workflow. \n• \nLeverage product analytics and onboarding platforms, including PostHog and Userflow, \nto track user journeys and optimize feature adoption. \n• \nCollaborate on EdTech Manager, a production-level micro-frontend application, utilizing \nReact, TypeScript, Vite Module Federation, and Redux. \n• \nSpearhead the engineering and remediation of WCAG accessibility compliance features, \nimproving keyboard navigation and screen-reader compatibility. \nUI Developer | Kongcepts | Kandy \nOct 2021 - Sep 2025 \n• \nDeveloped, maintained, and optimized corporate websites and landing pages, improving \nloading speeds by up to 50% through strategic code-splitting and asset optimization.  \n• \nTransformed complex Figma and Adobe XD wireframes into responsive, user-centric \nweb experiences using HTML5, CSS3, and JavaScript, maintaining a 100% client \napproval rating.  \n• \nSupported SEO initiatives by elevating organic search discoverability and boosting SEO \nscores by 20% to 35% using semantic HTML, structured schema markup, and metadata \noptimization.  \n• \nBoosted average user session duration by 40% on revamped client web applications by \nintroducing intuitive navigation and implementing UI/UX best practices.  \n• \nImplemented framework-level accessibility controls to bring legacy web projects up to \nstrict WCAG 2.1 AA standards.  \n \nProjects \nReal-Time Collaborative Jukebox Platform | Next.js, TypeScript, Firebase, Zustand, Vitest \nLive Demo: https://vibequeue.vercel.app | Repository: https://github.com/thusithakit/music-vote \n• \nArchitected a real-time collaborative platform with passcode-protected session states, \nmanaging instantaneous multi-user track submissions and live peer-presence tracking for \nconcurrent users. \n• \nDesigned a multi-tiered tie-breaker sorting algorithm using global state management and \nstate hooks to compute live queues instantly by Net Score, consensus filtering, and FIFO \ntimestamping. \n• \nEngineered client-side security mechanisms to sanitize streaming payloads, mitigating \nnetwork-tab exposure and ensuring metadata integrity during concurrent, blind voting \noperations.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-17T10:35:14+05:30', 'source': '..\\data\\pdf\\thusitha-kithuldora-cv-ipd.pdf', 'file_path': '..\\data\\pdf\\thusitha-kithuldora-cv-ipd.pdf', 'total_pages': 3, 'format': 'PDF 1.7', 'title': '', 'author': 'Thusitha Kithuldora', 'subject': '', 'keywords': '', 'moddate': '2026-07-17T10:35:14+05:30', 'trapped': '', 'modDate': "D:20260717103514+05'30'", 'creationDate': "D:20260717103514+05'30'", 'page': 2}, page_content='ConnectWithMe.digital Platform | Next.js, TypeScript, Prisma, Clerk, Cloudinary \nLive Demo: https://www.connectwithme.digital | Repository: https://github.com/thusithakit/share-\nmy-socials \n• \nEngineered a high-performance personal branding and profile-sharing application \nfeaturing secure multi-tenant authentication and dynamic, SEO-optimized public routing.  \n• \nIntegrated instant vCard contact serialization and automated canvas-based QR code \ngeneration engine to optimize cross-platform profile sharing capabilities.  \n• \nLeveraged automated cloud asset management pipelines for real-time media \ncompression, \nreducing \nasset \nloading \noverhead \nand \nimproving \nmulti-device \nresponsiveness. \nIoT-Enabled Smart Garbage Bin System (Final Year Project) | Next.js, TypeScript, Firebase \nLive Demo: https://go-green-khaki.vercel.app | Repository: https://github.com/thusithakit/go-\ngreen \n• \nArchitected a full-stack Progressive Web App (PWA) deploying 3 decoupled role-based \noperational dashboards supporting live stream telemetry for 10+ hardware nodes.  \n• \nProgrammed asynchronous hardware-to-cloud telemetry pipelines syncing ultrasonic and \nGPS data streams to Firebase, reducing manual inspection overhead by 70%.  \n• \nOptimized the client-side synchronization architecture to securely sustain 100+ concurrent \nuser connections with built-in local fallback caching and offline database support. \n \nCertifications and Badges \n• \nCreating Infrastructure on Google Cloud with Terraform - Google Cloud Skills Boost  \nIssued: Jan 2026 (Credential ID: 21509144) \n \n• \nGoogle Cloud Fundamentals: Core Infrastructure - Google Cloud Skills Boost  \nIssued: Oct 2025 (Credential ID: 19423909) \n \n• \nHTML/CSS Certificate - TestDome  \nIssued: Dec 2020 (Credential ID:5f1ad25f3c0e4df3ac3568749f44cb53) \n \nEducation \nBSc (Hons) in Electronics and Computer Science \nUniversity of Kelaniya, Sri Lanka \n2022 - 2026'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-06-21T18:30:16+05:30', 'source': '..\\data\\pdf\\thusitha-kithuldora-cv.pdf', 'file_path': '..\\data\\pdf\\thusitha-kithuldora-cv.pdf', 'total_pages': 3, 'format': 'PDF 1.7', 'title': '', 'author': 'Thusitha Kithuldora', 'subject': '', 'keywords': '', 'moddate': '2026-06-21T18:30:16+05:30', 'trapped': '', 'modDate': "D:20260621183016+05'30'", 'creationDate': "D:20260621183016+05'30'", 'page': 0}, page_content='Thusitha Kithuldora \nFrontend Focused Full-Stack Software Engineer \nColombo, Sri Lanka | +94762600331 | thusithakit3@gmail.com \nLinkedIn: thusitha-kithuldora | Portfolio: https://www.thusithakit.com \nProfessional Summary \nFrontend-focused Full-Stack Software Engineer with hands-on experience engineering scalable, \naccessible, and high-performance web applications. Proven track record in micro-frontend \narchitectures, client-side state management, and strict WCAG accessibility compliance. Adept at \nbridging the gap between pixel-perfect UI design and robust backend architectures to deliver \nseamless user experiences in agile environments. \nTechnical Skills \n• \nLanguages: TypeScript, JavaScript (ES6+), Java, Go (Golang), HTML5, CSS3/SASS  \n• \nFrontend Frameworks & Libraries: React, Next.js (App Router), Redux, Zustand, \nAxios, Vite Module Federation  \n• \nUI & Design Frameworks: Tailwind CSS, Chakra UI, Material UI, Ant Design, Figma, \nAdobe XD, Responsive & Component-Driven Design  \n• \nBackend, Databases & Cloud: Spring Boot, Echo (Golang), Google Cloud Platform \n(GCP), Terraform, MongoDB, MySQL, SQL Server, Firebase, Prisma ORM  \n• \nTools, Platforms & Concepts: Git/GitHub, REST APIs, Micro-frontends, PWA, SEO \nOptimization, Vitest, Postman, Vercel, Netlify \nProfessional Experience \nTrainee Software Engineer \n Qoria LK | Colombo \n Sep 2025 - Present \n• \nCollaborate on EdTech Insights, a production-level micro-frontend application, utilizing \nReact, TypeScript, Vite Module Federation, and Redux.  \n• \nSpearhead the engineering and remediation of WCAG accessibility compliance features, \nmarkedly improving keyboard navigation, ARIA labels, contrast ratios, and screen-reader \ncompatibility.  \n• \nDevelop high-impact client features, resolve critical production bugs, and execute UI/UX \nenhancements using Chakra UI and Axios.  \n• \nWrite and maintain comprehensive unit testing suites using Vitest to safeguard code \ncoverage and application stability.  \n• \nParticipate actively in agile ceremonies, working cross-functionally with UX designers, \nbackend teams, and product owners.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-06-21T18:30:16+05:30', 'source': '..\\data\\pdf\\thusitha-kithuldora-cv.pdf', 'file_path': '..\\data\\pdf\\thusitha-kithuldora-cv.pdf', 'total_pages': 3, 'format': 'PDF 1.7', 'title': '', 'author': 'Thusitha Kithuldora', 'subject': '', 'keywords': '', 'moddate': '2026-06-21T18:30:16+05:30', 'trapped': '', 'modDate': "D:20260621183016+05'30'", 'creationDate': "D:20260621183016+05'30'", 'page': 1}, page_content='UI Developer \n Kongcepts | Kandy \n Oct 2020 - January 2025 \n• \nOptimized website loading speeds by up to 50% across key corporate properties through \nstrategic image optimization, code-splitting, and AMP integration.  \n• \nTransformed complex Figma, PSD, and Adobe XD wireframes into pixel-perfect, \nresponsive code, maintaining a 100% client approval rating for major deliverables like \nKidamento.  \n• \nBoosted average user session duration by 40% on revamped client web applications by \nintroducing intuitive navigation and interactive elements.  \n• \nElevated organic search discoverability, boosting SEO scores by 20% to 35% using \nsemantic HTML, structured schema markup, and metadata optimization.  \n• \nImplemented framework-level accessibility controls to bring legacy web projects up to \nstrict WCAG 2.1 AA standards. \nProjects \nReal-Time Collaborative Jukebox Platform | Next.js, TypeScript, Firebase, Zustand, Vitest \nLive Demo: https://vibequeue.vercel.app | Repository: https://github.com/thusithakit/music-vote \n• \nArchitected a real-time collaborative platform with passcode-protected session states, \nmanaging instantaneous multi-user track submissions and live peer-presence tracking for \nconcurrent users. \n• \nDesigned a multi-tiered tie-breaker sorting algorithm using global state management and \nstate hooks to compute live queues instantly by Net Score, consensus filtering, and FIFO \ntimestamping. \n• \nEngineered client-side security mechanisms to sanitize streaming payloads, mitigating \nnetwork-tab exposure and ensuring metadata integrity during concurrent, blind voting \noperations. \n \nConnectWithMe.digital Platform | Next.js, TypeScript, Prisma, Clerk, Cloudinary \nLive Demo: https://www.connectwithme.digital | Repository: https://github.com/thusithakit/share-\nmy-socials \n• \nEngineered a high-performance personal branding and profile-sharing application \nfeaturing secure multi-tenant authentication and dynamic, SEO-optimized public routing.  \n• \nIntegrated instant vCard contact serialization and automated canvas-based QR code \ngeneration engine to optimize cross-platform profile sharing capabilities.  \n• \nLeveraged automated cloud asset management pipelines for real-time media \ncompression, \nreducing \nasset \nloading \noverhead \nand \nimproving \nmulti-device \nresponsiveness.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-06-21T18:30:16+05:30', 'source': '..\\data\\pdf\\thusitha-kithuldora-cv.pdf', 'file_path': '..\\data\\pdf\\thusitha-kithuldora-cv.pdf', 'total_pages': 3, 'format': 'PDF 1.7', 'title': '', 'author': 'Thusitha Kithuldora', 'subject': '', 'keywords': '', 'moddate': '2026-06-21T18:30:16+05:30', 'trapped': '', 'modDate': "D:20260621183016+05'30'", 'creationDate': "D:20260621183016+05'30'", 'page': 2}, page_content='IoT-Enabled Smart Garbage Bin System (Final Year Project) | Next.js, TypeScript, Firebase \nLive Demo: https://go-green-khaki.vercel.app | Repository: https://github.com/thusithakit/go-\ngreen \n• \nArchitected a full-stack Progressive Web App (PWA) deploying 3 decoupled role-based \noperational dashboards supporting live stream telemetry for 10+ hardware nodes.  \n• \nProgrammed asynchronous hardware-to-cloud telemetry pipelines syncing ultrasonic and \nGPS data streams to Firebase, reducing manual inspection overhead by 70%.  \n• \nOptimized the client-side synchronization architecture to securely sustain 100+ concurrent \nuser connections with built-in local fallback caching and offline database support. \n \nSanit.lk Business Website | Next.js, TypeScript, Netlify  \nLive Demo: https://sanit-opal.vercel.app | Repository: https://github.com/thusithakit/sanit \n• \nDeveloped an optimized web application leveraging 20+ atomic, reusable UI components \nstructured around component-driven design patterns.  \n• \nAchieved a 98+ Lighthouse Performance and SEO metric score by utilizing hybrid Server-\nSide Rendering (SSR) and automated structural meta optimization.  \n• \nManaged client-facing cycles across 10+ design-to-code feedback iterations to \nsuccessfully align interface specifications with production requirements. \n \nCertifications and Badges \n• \nCreating Infrastructure on Google Cloud with Terraform - Google Cloud Skills Boost  \nIssued: Jan 2026 (Credential ID: 21509144) \n \n• \nGoogle Cloud Fundamentals: Core Infrastructure - Google Cloud Skills Boost  \nIssued: Oct 2025 (Credential ID: 19423909) \n \n• \nHTML/CSS Certificate - TestDome  \nIssued: Dec 2020 (Credential ID:5f1ad25f3c0e4df3ac3568749f44cb53) \n \nEducation \nBSc (Hons) in Electronics and Computer Science \nUniversity of Kelaniya, Sri Lanka \n2022 - 2026'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-29T12:57:49+05:30', 'source': '..\\data\\pdf\\thusitha-kithuldora-fe-cv.pdf', 'file_path': '..\\data\\pdf\\thusitha-kithuldora-fe-cv.pdf', 'total_pages': 3, 'format': 'PDF 1.7', 'title': '', 'author': 'Thusitha Kithuldora', 'subject': '', 'keywords': '', 'moddate': '2026-07-29T12:57:49+05:30', 'trapped': '', 'modDate': "D:20260729125749+05'30'", 'creationDate': "D:20260729125749+05'30'", 'page': 0}, page_content='Thusitha Kithuldora \nFrontend Focused Full-Stack Software Engineer \nColombo, Sri Lanka | +94762600331 | thusithakit3@gmail.com \nLinkedIn: thusitha-kithuldora | Portfolio: https://www.thusithakit.com \nProfessional Summary \nResults-driven Software Engineer with a strong foundation in modern programming languages, \nincluding Java and JavaScript. Proven ability to deliver scalable, high-performance web \napplications and bridge hardware and software through IoT deployments. Highly proficient in AI-\nassisted development workflows, utilizing agentic frameworks to accelerate component \ngeneration while critically validating AI-generated code for security, performance, and \nmaintainability. Adept at agile methodologies, defect resolution, and collaborating across teams \nto engineer enterprise solutions. \nTechnical Skills \n• \nComputer Science Fundamentals: Data Structures, Algorithms, Object-Oriented \nProgramming (OOP), Agile Methodologies, Defect Resolution, Full-Stack \nDevelopment.  \n• \nLanguages: Java, TypeScript, JavaScript (ES6+), Go (Golang), HTML5, CSS3/SASS.  \n• \nFrontend Frameworks & Libraries: React, Next.js (App Router), Redux, Zustand, \nAxios, Vite Module Federation.  \n• \nBackend, Databases & Cloud: Node.JS, Spring Boot, Echo (Golang), Google Cloud \nPlatform (GCP), Terraform, MongoDB, MySQL, SQL Server, Firebase, Prisma ORM.  \n• \nTesting & Code Quality: Vitest, Cypress, Playwright, SonarQube, Snyk.  \n• \nAI & Developer Tools: GitHub Copilot, Cursor, Claude code, AI-Assisted Component \nGeneration, Code Refactoring, Git/GitHub, REST APIs, Postman, Vercel, Netlify.  \n• \nAnalytics & Platforms: PostHog, Userflow, Micro-frontends, PWA, SEO Optimization. \n \nProfessional Experience \nTrainee Software Engineer \n Qoria LK | Colombo \n Sep 2025 - Present \n• \nTook full ownership of the design and frontend development for the new Public App \nDirectory, delivering a high-impact feature anticipated to drive major adoption for the \nEdTech Manager product during the back-to-school season.  \n• \nIntegrated AI coding assistants into daily workflows to accelerate UI component \ncreation, test generation, and code refactoring, consistently reviewing outputs to \nensure strict adherence to security and architectural standards. \n• \nParticipate actively in agile ceremonies, working cross-functionally with UX designers, \nbackend teams, and product owners to deliver software components.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-29T12:57:49+05:30', 'source': '..\\data\\pdf\\thusitha-kithuldora-fe-cv.pdf', 'file_path': '..\\data\\pdf\\thusitha-kithuldora-fe-cv.pdf', 'total_pages': 3, 'format': 'PDF 1.7', 'title': '', 'author': 'Thusitha Kithuldora', 'subject': '', 'keywords': '', 'moddate': '2026-07-29T12:57:49+05:30', 'trapped': '', 'modDate': "D:20260729125749+05'30'", 'creationDate': "D:20260729125749+05'30'", 'page': 1}, page_content='• \nInvestigate and resolve critical production bugs, and execute UI/UX enhancements \nusing Chakra UI and Axios.  \n• \nWrite and maintain comprehensive end-to-end and unit testing suites utilizing Vitest, \nCypress, and Playwright to safeguard application stability.  \n• \nEnforce strict engineering best practices and secure code standards by integrating \nSonarQube and Snyk into the development workflow.  \n• \nUse product analytics and onboarding platforms, including PostHog and Userflow, to \ntrack user journeys and optimize feature adoption.  \n• \nCollaborate on EdTech Manager, a production-level micro-frontend application, \nutilizing React, TypeScript, Vite Module Federation, and Redux.  \n• \nSpearhead the engineering and remediation of WCAG accessibility compliance \nfeatures, improving keyboard navigation and screen-reader compatibility. \n \nUI Developer \n Kongcepts | Kandy \n Oct 2022 - January 2025 \n• \nOptimized website loading speeds by up to 50% across key corporate properties \nthrough strategic image optimization, code-splitting, and AMP integration.  \n• \nTransformed complex Figma, PSD, and Adobe XD wireframes into responsive code, \nmaintaining a 100% client approval rating for major deliverables.  \n• \nBoosted average user session duration by 40% on revamped client web applications \nby introducing intuitive navigation and interactive elements.  \n• \nImproved organic search discoverability, boosting SEO scores by 20% to 35% using \nsemantic HTML, structured schema markup, and metadata optimization.  \n• \nImplemented framework-level accessibility controls to bring legacy web projects up to \nstrict WCAG 2.1 AA standards. \n \nProjects \nReal-Time Collaborative Jukebox Platform | Next.js, TypeScript, Firebase, Zustand, Vitest \nLive Demo: https://vibequeue.vercel.app | Repository: https://github.com/thusithakit/music-vote \n• \nArchitected a real-time collaborative platform with passcode-protected session states, \nmanaging instantaneous multi-user track submissions and live peer-presence tracking for \nconcurrent users. \n• \nDesigned a multi-tiered tie-breaker sorting algorithm using global state management and \nstate hooks to compute live queues instantly by Net Score, consensus filtering, and FIFO \ntimestamping. \n• \nEngineered client-side security mechanisms to sanitize streaming payloads, mitigating \nnetwork-tab exposure and ensuring metadata integrity during concurrent, blind voting \noperations.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-29T12:57:49+05:30', 'source': '..\\data\\pdf\\thusitha-kithuldora-fe-cv.pdf', 'file_path': '..\\data\\pdf\\thusitha-kithuldora-fe-cv.pdf', 'total_pages': 3, 'format': 'PDF 1.7', 'title': '', 'author': 'Thusitha Kithuldora', 'subject': '', 'keywords': '', 'moddate': '2026-07-29T12:57:49+05:30', 'trapped': '', 'modDate': "D:20260729125749+05'30'", 'creationDate': "D:20260729125749+05'30'", 'page': 2}, page_content='ConnectWithMe.digital Platform | Next.js, TypeScript, Prisma, Clerk, Cloudinary \nLive Demo: https://www.connectwithme.digital | Repository: https://github.com/thusithakit/share-\nmy-socials \n• \nEngineered a high-performance personal branding and profile-sharing application \nfeaturing secure multi-tenant authentication and dynamic, SEO-optimized public routing.  \n• \nIntegrated instant vCard contact serialization and automated canvas-based QR code \ngeneration engine to optimize cross-platform profile sharing capabilities.  \n• \nLeveraged automated cloud asset management pipelines for real-time media \ncompression, \nreducing \nasset \nloading \noverhead \nand \nimproving \nmulti-device \nresponsiveness. \nSanit.lk Business Website | Next.js, TypeScript, Netlify  \nLive Demo: https://sanit-opal.vercel.app | Repository: https://github.com/thusithakit/sanit \n• \nDeveloped an optimized web application leveraging 20+ atomic, reusable UI components \nstructured around component-driven design patterns.  \n• \nAchieved a 98+ Lighthouse Performance and SEO metric score by utilizing hybrid Server-\nSide Rendering (SSR) and automated structural meta optimization.  \n• \nManaged client-facing cycles across 10+ design-to-code feedback iterations to \nsuccessfully align interface specifications with production requirements. \n \n \nCertifications and Badges \n• \nCreating Infrastructure on Google Cloud with Terraform - Google Cloud Skills Boost  \nIssued: Jan 2026 (Credential ID: 21509144) \n \n• \nGoogle Cloud Fundamentals: Core Infrastructure - Google Cloud Skills Boost  \nIssued: Oct 2025 (Credential ID: 19423909) \n \n• \nHTML/CSS Certificate - TestDome  \nIssued: Dec 2020 (Credential ID:5f1ad25f3c0e4df3ac3568749f44cb53) \n \nEducation \nBSc (Hons) in Electronics and Computer Science \nUniversity of Kelaniya, Sri Lanka \n2022 - 2026'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-16T19:06:01+05:30', 'source': '..\\data\\pdf\\thusitha-kithuldora-se-cv.pdf', 'file_path': '..\\data\\pdf\\thusitha-kithuldora-se-cv.pdf', 'total_pages': 3, 'format': 'PDF 1.7', 'title': '', 'author': 'Thusitha Kithuldora', 'subject': '', 'keywords': '', 'moddate': '2026-07-16T19:06:01+05:30', 'trapped': '', 'modDate': "D:20260716190601+05'30'", 'creationDate': "D:20260716190601+05'30'", 'page': 0}, page_content='Thusitha Kithuldora \nFull-Stack Software Engineer \nColombo, Sri Lanka | +94762600331 | thusithakit3@gmail.com \nLinkedIn: thusitha-kithuldora | Portfolio: https://www.thusithakit.com \nProfessional Summary \nResults-driven Software Engineer with a strong foundation in modern programming languages, \nincluding Java and JavaScript. Proven ability to bridge hardware and software through IoT \ndeployments and deliver scalable, high-performance web applications. Adept at agile \nmethodologies, defect resolution, and collaborating across teams to engineer robust enterprise \nsolutions. \nTechnical Skills \n• \nComputer Science Fundamentals: Data Structures, Algorithms, Object-Oriented \nProgramming (OOP), Agile Methodologies, Defect Resolution, Full-Stack Development. \n• \nLanguages: Java, TypeScript, JavaScript (ES6+), Go (Golang), HTML5, CSS3/SASS. \n• \nFrontend Frameworks & Libraries: React, Next.js (App Router), Redux, Zustand, \nAxios, Vite Module Federation. \n• \nBackend, Databases & Cloud: Spring Boot, Echo (Golang), Google Cloud Platform \n(GCP), Terraform, MongoDB, MySQL, SQL Server, Firebase, Prisma ORM. \n• \nTesting & Code Quality: Vitest, Cypress, Playwright, SonarQube, Snyk. \n• \nTools, Analytics & Platforms: Git/GitHub, REST APIs, PostHog, Userflow, Micro-\nfrontends, PWA, SEO Optimization, Postman, Vercel, Netlify. \nProfessional Experience \nTrainee Software Engineer | Qoria LK | Colombo \n Sep 2025 - Present \n• \nTook full ownership of the design and frontend development for the new Public App \nDirectory, delivering a high-impact feature anticipated to drive major adoption for the \nEdTech Manager product during the back-to-school season. \n• \nParticipate actively in agile ceremonies, working cross-functionally with UX designers, \nbackend teams, and product owners to deliver software components. \n• \nInvestigate and resolve critical production bugs, and execute UI/UX enhancements using \nChakra UI and Axios. \n• \nWrite and maintain comprehensive end-to-end and unit testing suites utilizing Vitest, \nCypress, and Playwright to safeguard application stability. \n• \nEnforce strict engineering best practices and secure code standards by integrating \nSonarQube and Snyk into the development workflow. \n• \nLeverage product analytics and onboarding platforms, including PostHog and Userflow, \nto track user journeys and optimize feature adoption.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-16T19:06:01+05:30', 'source': '..\\data\\pdf\\thusitha-kithuldora-se-cv.pdf', 'file_path': '..\\data\\pdf\\thusitha-kithuldora-se-cv.pdf', 'total_pages': 3, 'format': 'PDF 1.7', 'title': '', 'author': 'Thusitha Kithuldora', 'subject': '', 'keywords': '', 'moddate': '2026-07-16T19:06:01+05:30', 'trapped': '', 'modDate': "D:20260716190601+05'30'", 'creationDate': "D:20260716190601+05'30'", 'page': 1}, page_content='• \nCollaborate on EdTech Manager, a production-level micro-frontend application, utilizing \nReact, TypeScript, Vite Module Federation, and Redux. \n• \nSpearhead the engineering and remediation of WCAG accessibility compliance features, \nimproving keyboard navigation and screen-reader compatibility. \nUI Developer | Kongcepts | Kandy \nOct 2023 - Sep 2025 \n• \nOptimized website loading speeds by up to 50% across key corporate properties through \nstrategic image optimization, code-splitting, and AMP integration.  \n• \nTransformed complex Figma, PSD, and Adobe XD wireframes into responsive code, \nmaintaining a 100% client approval rating for major deliverables.  \n• \nBoosted average user session duration by 40% on revamped client web applications by \nintroducing intuitive navigation and interactive elements.  \n• \nElevated organic search discoverability, boosting SEO scores by 20% to 35% using \nsemantic HTML, structured schema markup, and metadata optimization.  \n• \nImplemented framework-level accessibility controls to bring legacy web projects up to \nstrict WCAG 2.1 AA standards. \nProjects \nReal-Time Collaborative Jukebox Platform | Next.js, TypeScript, Firebase, Zustand, Vitest \nLive Demo: https://vibequeue.vercel.app | Repository: https://github.com/thusithakit/music-vote \n• \nArchitected a real-time collaborative platform with passcode-protected session states, \nmanaging instantaneous multi-user track submissions and live peer-presence tracking for \nconcurrent users. \n• \nDesigned a multi-tiered tie-breaker sorting algorithm using global state management and \nstate hooks to compute live queues instantly by Net Score, consensus filtering, and FIFO \ntimestamping. \n• \nEngineered client-side security mechanisms to sanitize streaming payloads, mitigating \nnetwork-tab exposure and ensuring metadata integrity during concurrent, blind voting \noperations. \n \nConnectWithMe.digital Platform | Next.js, TypeScript, Prisma, Clerk, Cloudinary \nLive Demo: https://www.connectwithme.digital | Repository: https://github.com/thusithakit/share-\nmy-socials \n• \nEngineered a high-performance personal branding and profile-sharing application \nfeaturing secure multi-tenant authentication and dynamic, SEO-optimized public routing.  \n• \nIntegrated instant vCard contact serialization and automated canvas-based QR code \ngeneration engine to optimize cross-platform profile sharing capabilities.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-16T19:06:01+05:30', 'source': '..\\data\\pdf\\thusitha-kithuldora-se-cv.pdf', 'file_path': '..\\data\\pdf\\thusitha-kithuldora-se-cv.pdf', 'total_pages': 3, 'format': 'PDF 1.7', 'title': '', 'author': 'Thusitha Kithuldora', 'subject': '', 'keywords': '', 'moddate': '2026-07-16T19:06:01+05:30', 'trapped': '', 'modDate': "D:20260716190601+05'30'", 'creationDate': "D:20260716190601+05'30'", 'page': 2}, page_content='• \nLeveraged automated cloud asset management pipelines for real-time media \ncompression, \nreducing \nasset \nloading \noverhead \nand \nimproving \nmulti-device \nresponsiveness. \n \n \nIoT-Enabled Smart Garbage Bin System (Final Year Project) | Next.js, TypeScript, Firebase \nLive Demo: https://go-green-khaki.vercel.app | Repository: https://github.com/thusithakit/go-\ngreen \n• \nArchitected a full-stack Progressive Web App (PWA) deploying 3 decoupled role-based \noperational dashboards supporting live stream telemetry for 10+ hardware nodes.  \n• \nProgrammed asynchronous hardware-to-cloud telemetry pipelines syncing ultrasonic and \nGPS data streams to Firebase, reducing manual inspection overhead by 70%.  \n• \nOptimized the client-side synchronization architecture to securely sustain 100+ concurrent \nuser connections with built-in local fallback caching and offline database support. \n \nCertifications and Badges \n• \nCreating Infrastructure on Google Cloud with Terraform - Google Cloud Skills Boost  \nIssued: Jan 2026 (Credential ID: 21509144) \n \n• \nGoogle Cloud Fundamentals: Core Infrastructure - Google Cloud Skills Boost  \nIssued: Oct 2025 (Credential ID: 19423909) \n \n• \nHTML/CSS Certificate - TestDome  \nIssued: Dec 2020 (Credential ID:5f1ad25f3c0e4df3ac3568749f44cb53) \n \nEducation \nBSc (Hons) in Electronics and Computer Science \nUniversity of Kelaniya, Sri Lanka \n2022 - 2026')]
